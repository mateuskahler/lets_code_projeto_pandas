# %% [markdown]
# ### Teste de análise das variáveis qualitativas

# %%
from leitura import carregar_dados
from qualitativas import analisar_variaveis_qualitativas

df = carregar_dados()

print(type(df))
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    ID Region Main Source of Income  Agricultural Household indicator  \
# 0   1      A         Wage/Salaries                                 0
# 1   2      A         Wage/Salaries                                 0
# 2   3      A         Wage/Salaries                                 1
# 3   4      A         Wage/Salaries                                 0
# 4   5      A         Wage/Salaries                                 0
#
#   Household Head Sex  Household Head Age Household Head Marital Status  \
# 0             Female                  49                        Single
# 1               Male                  40                       Married
# 2               Male                  39                       Married
# 3               Male                  52                       Married
# 4               Male                  65                       Married
#
#                      Household Head Class of Worker Type of Household  \
# ...

# %%
analises_variaveis_qualitativas = analisar_variaveis_qualitativas(df)

# %%
import matplotlib.pyplot as plt

for variavel_analisada in analises_variaveis_qualitativas:
    print(variavel_analisada.nome_da_variavel)
    for analise in variavel_analisada.analises:
        print(analise.nome)
        analise.dados.plot(kind='bar')
        plt.show()
# Out:
# Region
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Main Source of Income
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Household Head Sex
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Household Head Marital Status
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Household Head Class of Worker
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Type of Household
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Type of Building/House
# Frequência Absoluta
# Frequência Absoluta Acumulada
# Frequência Relativa
# Frequência Relativa Acumulada
# Type of Walls
# Frequência Absoluta
# Frequência Absoluta Acumulada
# ...
