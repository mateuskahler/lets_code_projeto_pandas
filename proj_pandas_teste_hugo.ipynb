# %%
import pandas as pd
import top10
import dummies

# %%
df_demografico = pd.read_csv('1_demografico.csv', sep=';')

# %%
df_renda_gastos = pd.read_csv('2_renda_gastos.csv', sep=';')

# %%
df_bens = pd.read_csv('3_bens.csv', sep=';')

# %%
df = df_demografico.merge(df_renda_gastos, on=['ID', 'Region'], how='outer')

# %%
df = df.merge(df_bens, left_index=True, right_index=True)

# %%
df
# Out:
#          ID Region       Main Source of Income  \
# 0         1      A               Wage/Salaries
# 1         2      A               Wage/Salaries
# 2         3      A               Wage/Salaries
# 3         4      A               Wage/Salaries
# 4         5      A               Wage/Salaries
# ...     ...    ...                         ...
# 41539  1784      Q  Enterpreneurial Activities
# 41540  1785      Q               Wage/Salaries
# 41541  1786      Q  Enterpreneurial Activities
# 41542  1787      Q  Enterpreneurial Activities
# 41543  1788      Q     Other sources of Income
#
#        Agricultural Household indicator Household Head Sex  \
# 0                                     0             Female
# 1                                     0               Male
# 2                                     1               Male
# 3                                     0               Male
# 4                                     0               Male
# ...

# %% [markdown]
# 6) Separe os 10% com maior renda(Ordem decrescente) em um novo csv

# %%
top10.salvar_top10(df, 'Total Household Income', 'top10_income.csv')
# Out:
#          ID Region       Main Source of Income  \
# 3860    354      C     Other sources of Income
# 3513      7      C     Other sources of Income
# 29329  1760      L  Enterpreneurial Activities
# 21291   596      I  Enterpreneurial Activities
# 35476  3222      N  Enterpreneurial Activities
# ...     ...    ...                         ...
# 4612   1106      C  Enterpreneurial Activities
# 33528  1274      N               Wage/Salaries
# 32881   627      N               Wage/Salaries
# 29746  2177      L     Other sources of Income
# 36169  3915      N               Wage/Salaries
#
#        Agricultural Household indicator Household Head Sex  \
# 3860                                  0               Male
# 3513                                  0               Male
# 29329                                 0               Male
# 21291                                 0               Male
# 35476                                 2               Male
# ...

# %% [markdown]
# 7) Criar os dummies para pelo menos 3 das variáveis qualitativas

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Region', 'Main Source of Income', 'Household Head Sex',
#        'Household Head Marital Status', 'Household Head Class of Worker',
#        'Type of Household', 'Type of Building/House', 'Type of Walls'],
#       dtype='object')

# %%
#retornar apenas as colunas dummies
dummies.criar_dummies(df, ['Main Source of Income', 'Household Head Sex', 'Type of Household'])
# Out:
#        Main Source of Income_Enterpreneurial Activities  \
# 0                                                     0
# 1                                                     0
# 2                                                     0
# 3                                                     0
# 4                                                     0
# ...                                                 ...
# 41539                                                 1
# 41540                                                 0
# 41541                                                 1
# 41542                                                 1
# 41543                                                 0
#
#        Main Source of Income_Other sources of Income  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# ...

# %%
#retornar todo o dataframe com as dummies
dummies.criar_dummies(df, ['Main Source of Income', 'Household Head Sex', 'Type of Household'], True)
# Out:
#          ID Region       Main Source of Income  \
# 0         1      A               Wage/Salaries
# 1         2      A               Wage/Salaries
# 2         3      A               Wage/Salaries
# 3         4      A               Wage/Salaries
# 4         5      A               Wage/Salaries
# ...     ...    ...                         ...
# 41539  1784      Q  Enterpreneurial Activities
# 41540  1785      Q               Wage/Salaries
# 41541  1786      Q  Enterpreneurial Activities
# 41542  1787      Q  Enterpreneurial Activities
# 41543  1788      Q     Other sources of Income
#
#        Agricultural Household indicator Household Head Sex  \
# 0                                     0             Female
# 1                                     0               Male
# 2                                     1               Male
# 3                                     0               Male
# 4                                     0               Male
# ...
